# %%
import pandas as pd

# %%
df1 = pd.read_excel('c:/3rd_project/data/images/movie/[메인장르_주요색상_임베딩] 영화포스터(2011.01-2023.07).xlsx', engine='openpyxl')
df2 = pd.read_csv('c:/3rd_project/data/Train/movie_data_230929.csv')

# %%
df1
# Out:
#         idx                                영화명         개봉일        등급       장르  \
# 0      4658                    잃어버린 마법의 섬 홋타라케  2011-01-02     전체관람가    애니메이션
# 1      4660  극장판 메탈 베이블레이드 VS 태양 작열의 침략자 솔블레이즈  2011-01-05     전체관람가    애니메이션
# 2      4661                             동자 대소동  2011-01-05     전체관람가   가족,코미디
# 3      4662                             심장이 뛴다  2011-01-05  15세이상관람가      드라마
# 4      4663                           내 친구의 소원  2011-01-06  15세이상관람가  코미디,드라마
# ...     ...                                ...         ...       ...      ...
# 7000  18416                              붉은 사막  2023-07-26  15세이상관람가      드라마
# 7001  18417                              비닐하우스  2023-07-26  15세이상관람가       범죄
# 7002  18418                              에고이스트  2023-07-26   청소년관람불가      드라마
# 7003  18419         핑크퐁 시네마 콘서트3 : 진저브레드맨을 잡아라  2023-07-26     전체관람가    애니메이션
# 7004  18420                             헌티드 맨션  2023-07-26  12세이상관람가   공포(호러)
#
# ...

# %%
df1[['메인장르', 'embedding1', 'embedding2', 'embedding3']]
# Out:
#         메인장르 embedding1 embedding2 embedding3
# 0      애니메이션      애니메이션      애니메이션      애니메이션
# 1      애니메이션      애니메이션      애니메이션      애니메이션
# 2        코미디        드라마         액션         액션
# 3        드라마        드라마          -        드라마
# 4        코미디          -        드라마     공포(호러)
# ...      ...        ...        ...        ...
# 7000     드라마     공포(호러)        드라마     공포(호러)
# 7001       -     공포(호러)        드라마        드라마
# 7002     드라마        드라마        드라마        코미디
# 7003   애니메이션      애니메이션      애니메이션      애니메이션
# 7004  공포(호러)          -         액션         액션
#
# [7005 rows x 4 columns]

# %%
df2.head(3)
# Out:
#                             img_name  airplane  apple  backpack  banana  \
# 0                    잃어버린 마법의 섬 홋타라케         0      0         0       0
# 1  극장판 메탈 베이블레이드 VS 태양 작열의 침략자 솔블레이즈         0      0         0       0
# 2                             동자 대소동         0      0         0       0
#
#    baseball bat  baseball glove  bear  bed  bench  ...  color_1_r  color_1_g  \
# 0             0               0     0    0      0  ...     0.3882     0.6353
# 1             0               0     0    0      0  ...     0.1961     0.1451
# 2             0               0     0    0      0  ...     0.2824     0.1961
#
#    color_1_b  color_2_r  color_2_g  color_2_b  color_3_r  color_3_g  \
# 0     0.6980     0.3294     0.3294     0.2784     0.8392     0.8824
# 1     0.1804     0.6667     0.4039     0.3216     0.8000     0.7922
# 2     0.1373     0.9098     0.8275     0.7608     0.7059     0.4784
#
#    color_3_b  genre
# 0     0.9020  애니메이션
# 1     0.7725  애니메이션
# 2     0.3373    코미디
#
# ...

# %%
df1[df1.columns[-3:]]
# Out:
#      embedding1 embedding2 embedding3
# 0         애니메이션      애니메이션      애니메이션
# 1         애니메이션      애니메이션      애니메이션
# 2           드라마         액션         액션
# 3           드라마          -        드라마
# 4             -        드라마     공포(호러)
# ...         ...        ...        ...
# 7000     공포(호러)        드라마     공포(호러)
# 7001     공포(호러)        드라마        드라마
# 7002        드라마        드라마        코미디
# 7003      애니메이션      애니메이션      애니메이션
# 7004          -         액션         액션
#
# [7005 rows x 3 columns]
