# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('c:/3rd_project/data/Train/movie_data_231012_total.csv')
df
# Out:
#         idx                                영화명 embedding1 embedding2  \
# 0      4658                    잃어버린 마법의 섬 홋타라케      애니메이션      애니메이션
# 1      4660  극장판 메탈 베이블레이드 VS 태양 작열의 침략자 솔블레이즈      애니메이션      애니메이션
# 2      4661                             동자 대소동        드라마         액션
# 3      4662                             심장이 뛴다        드라마          -
# 4      4663                           내 친구의 소원          -        드라마
# ...     ...                                ...        ...        ...
# 7000  18416                              붉은 사막     공포(호러)        드라마
# 7001  18417                              비닐하우스     공포(호러)        드라마
# 7002  18418                              에고이스트        드라마        드라마
# 7003  18419         핑크퐁 시네마 콘서트3 : 진저브레드맨을 잡아라      애니메이션      애니메이션
# 7004  18420                             헌티드 맨션          -         액션
#
#      embedding3  vehicle  food  animal  bird  person  ...  color_4_b  \
# ...

# %%
act_genre = df[df['genre'] == '액션']
act_avg_freq = act_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

ani_genre = df[df['genre'] == '애니메이션']
ani_avg_freq = ani_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

com_genre = df[df['genre'] == '코미디']
com_avg_freq = com_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

dra_genre = df[df['genre'] == '드라마']
dra_avg_freq = dra_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

hor_genre = df[df['genre'] == '공포(호러)']
hor_avg_freq = hor_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

etc_genre = df[df['genre'] == '-']
etc_avg_freq = etc_genre[['act_freq', 'ani_freq', 'com_freq', 'dra_freq', 'hor_freq']].mean()

# %%
import matplotlib.pyplot as plt

# 열 이름
columns = act_avg_freq.index

# 평균 값
act_freq_values = act_avg_freq.values
ani_freq_values = ani_avg_freq.values
com_freq_values = com_avg_freq.values
dra_freq_values = dra_avg_freq.values
hor_freq_values = hor_avg_freq.values
etc_freq_values = etc_avg_freq.values

plt.figure(figsize=(12, 6))

x = range(len(columns))  # X축 값

plt.plot(x, act_freq_values, marker='o', label='act', color='#4169E1')
plt.plot(x, ani_freq_values, marker='o', label='ani', color='#FF6347')
plt.plot(x, com_freq_values, marker='o', label='com', color='#FFD700')
plt.plot(x, dra_freq_values, marker='o', label='dra', color='#90EE90')
plt.plot(x, hor_freq_values, marker='o', label='hor', color='#DDA0DD')
plt.plot(x, etc_freq_values, marker='o', label='etc', color='#FF8C00')

plt.title('Genre Frequency')
plt.xlabel('Genre Frequency')
plt.ylabel('Avg Frequency')
plt.xticks(x, columns)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# 열 이름
columns = act_avg_freq.index

# 평균 값
act_freq_values = act_avg_freq.values
ani_freq_values = ani_avg_freq.values
com_freq_values = com_avg_freq.values
dra_freq_values = dra_avg_freq.values
hor_freq_values = hor_avg_freq.values
etc_freq_values = etc_avg_freq.values

width = 0.15  # 각 막대의 너비

plt.figure(figsize=(12, 6))

x = range(len(columns))  # X축 값

plt.bar(x, act_freq_values, width, label='act', color='#4169E1')
plt.bar([i + width for i in x], ani_freq_values, width, label='ani', color='#FF6347')
plt.bar([i + 2 * width for i in x], com_freq_values, width, label='com', color='#FFD700')
plt.bar([i + 3 * width for i in x], dra_freq_values, width, label='dra', color='#90EE90')
plt.bar([i + 4 * width for i in x], hor_freq_values, width, label='hor', color='#DDA0DD')
plt.bar([i + 5 * width for i in x], etc_freq_values, width, label='etc', color='#FF8C00')

plt.title('Genre Frequency')
plt.xlabel('Genre Frequency')
plt.ylabel('Avg Frequency')
plt.xticks([i + 2.5 * width for i in x], columns)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
act_freq_values
# Out:
# array([4.82689655, 0.63241379, 0.41241379, 0.48965517, 0.05103448])

# %%
import matplotlib.pyplot as plt


# 라벨
labels = hor_avg_freq.index

# 색상
colors = ['#4169E1', '#FF6347', '#FFD700', '#90EE90', '#DDA0DD']

# 파이 차트 그리기
explode = (0, 0, 0, 0, 0.05)  # "dra_freq"를 약간 떼어냄
plt.pie(hor_freq_values, colors=colors, autopct='%1.1f%%', startangle=188, explode=explode)  # 비율 표시

plt.axis('equal')  # 원 모양을 유지
plt.legend(labels, prop={'size': 8}, loc="upper left")

# 차트 제목
plt.title("Horror Movie")

# 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt


# 라벨
labels = act_avg_freq.index

# 색상
colors = ['#4169E1', '#FF6347', '#FFD700', '#90EE90', '#DDA0DD']

# 파이 차트 그리기
explode = (0.05, 0, 0, 0, 0)  # "dra_freq"를 약간 떼어냄
plt.pie(act_freq_values, colors=colors, autopct='%1.1f%%', startangle=180, explode=explode)  # 비율 표시)  # 비율 표시

plt.axis('equal')  # 원 모양을 유지
plt.legend(labels, prop={'size': 8}, loc="upper left")

# 차트 제목
plt.title("Action Movie")

# 보여주기
plt.show()

# %%
act_genre = df[df['genre'] == '액션']
act_avg_obj = act_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

ani_genre = df[df['genre'] == '애니메이션']
ani_avg_obj = ani_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

com_genre = df[df['genre'] == '코미디']
com_avg_obj = com_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

dra_genre = df[df['genre'] == '드라마']
dra_avg_obj = dra_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

hor_genre = df[df['genre'] == '공포(호러)']
hor_avg_obj = hor_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

etc_genre = df[df['genre'] == '-']
etc_avg_obj = etc_genre[['vehicle', 'food', 'animal', 'bird', 'person', 'objects', 'electronic products', 'computer', 'sport', 'weapon', 'eating utensil', 'bag', 'etc']].mean()

# %%
# 열 이름
columns = act_avg_obj.index

# 평균 값
act_obj_values = act_avg_obj.values
ani_obj_values = ani_avg_obj.values
com_obj_values = com_avg_obj.values
dra_obj_values = dra_avg_obj.values
hor_obj_values = hor_avg_obj.values
etc_obj_values = etc_avg_obj.values

width = 0.15  # 각 막대의 너비

plt.figure(figsize=(12, 6))

x = range(len(columns))  # X축 값

plt.bar(x, act_obj_values, width, label='act_obj', color='#4169E1')
plt.bar([i + width for i in x], ani_obj_values, width, label='ani_obj', color='#FF6347')
plt.bar([i + 2 * width for i in x], com_obj_values, width, label='com_obj', color='#FFD700')
plt.bar([i + 3 * width for i in x], dra_obj_values, width, label='dra_obj', color='#90EE90')
plt.bar([i + 4 * width for i in x], hor_obj_values, width, label='hor_obj', color='#DDA0DD')
plt.bar([i + 5 * width for i in x], etc_obj_values, width, label='etc_obj', color='#FF8C00')

plt.title('Genre Object')
plt.xlabel('Object')
plt.ylabel('Avg Object')
plt.xticks([i + 2.5 * width for i in x], columns, rotation=45, horizontalalignment='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
print(f"{act_obj_values}\n")
print(f"{ani_obj_values}\n")
print(f"{com_obj_values}\n")
print(f"{dra_obj_values}\n")
print(f"{hor_obj_values}\n")
print(f"{etc_obj_values}\n")
# Out:
# [0.06551724 0.03862069 0.11793103 0.00827586 1.75793103 0.12137931
#  0.01793103 0.09034483 0.04551724 0.02413793 0.01103448 0.00206897
#  0.02827586]
#
# [0.06765068 0.10947109 0.77859779 0.01353014 0.95448954 0.12546125
#  0.00861009 0.02214022 0.05781058 0.00246002 0.01722017 0.
#  0.13284133]
#
# [7.16253444e-02 7.43801653e-02 1.29476584e-01 5.50964187e-03
#  3.06336088e+00 2.32782369e-01 2.61707989e-02 3.58126722e-02
#  6.88705234e-02 2.75482094e-03 7.16253444e-02 5.50964187e-03
#  9.77961433e-02]
#
# [0.04311688 0.04311688 0.11844156 0.00935065 2.13506494 0.2025974
#  0.02285714 0.05142857 0.04519481 0.00311688 0.04519481 0.00623377
#  0.1174026 ]
#
# [0.04395604 0.02930403 0.12454212 0.00549451 0.87728938 0.09157509
#  0.03846154 0.08058608 0.01282051 0.00549451 0.00732601 0.0018315
#  0.05494505]
#
# [0.0407767  0.05566343 0.14045307 0.01035599 1.68737864 0.13074434
#  0.02459547 0.05760518 0.03883495 0.00647249 0.03236246 0.00194175
#  0.09190939]

# %%
import numpy as np

print(f"액션 : {np.argsort(act_obj_values)[-3:]}\n")
print(f"{act_obj_values[2]}\t{act_obj_values[5]}\t{act_obj_values[4]}\n")

print(f"애니메이션 : {np.argsort(ani_obj_values)[-3:]}\n")
print(f"{ani_obj_values[12]}\t{ani_obj_values[2]}\t{ani_obj_values[4]}\n")

print(f"코미디 : {np.argsort(com_obj_values)[-3:]}\n")
print(f"{com_obj_values[2]}\t{com_obj_values[5]}\t{com_obj_values[4]}\n")

print(f"드라마 : {np.argsort(dra_obj_values)[-3:]}\n")
print(f"{dra_obj_values[2]}\t{dra_obj_values[5]}\t{dra_obj_values[4]}\n")

print(f"공포 : {np.argsort(hor_obj_values)[-3:]}\n")
print(f"{hor_obj_values[5]}\t{hor_obj_values[2]}\t{hor_obj_values[4]}\n")

print(f"기타 : {np.argsort(etc_obj_values)[-3:]}\n")
print(f"{etc_obj_values[5]}\t{etc_obj_values[2]}\t{etc_obj_values[4]}\n")
# Out:
# 액션 : [2 5 4]
#
# 0.11793103448275861	0.12137931034482759	1.7579310344827586
#
# 애니메이션 : [12  2  4]
#
# 0.13284132841328414	0.7785977859778598	0.9544895448954489
#
# 코미디 : [2 5 4]
#
# 0.12947658402203857	0.2327823691460055	3.0633608815426996
#
# 드라마 : [2 5 4]
#
# 0.11844155844155844	0.2025974025974026	2.135064935064935
#
# 공포 : [5 2 4]
#
# 0.09157509157509157	0.12454212454212454	0.8772893772893773
#
# 기타 : [5 2 4]
#
# 0.1307443365695793	0.14045307443365695	1.687378640776699
